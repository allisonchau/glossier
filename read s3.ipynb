# %%
import json
import datetime
import os
import pandas as pd
from collections import Counter
import requests
from io import BytesIO
from zipfile import ZipFile

# %%
r=requests.get('https://s3.amazonaws.com/data-eng-homework/v1/data.zip')

# %%
print(r.status_code)
print(r.headers['content-type'])
print(r.encoding)
# Out:
# 200
# application/zip
# None

# %%
r.text

# %%
def download_extract_zip(url):

    with ZipFile(BytesIO(r.content)) as thezip:
        for zipinfo in thezip.infolist():
            with thezip.open(zipinfo) as thefile:
                yield zipinfo.filename, thefile

# %%
obj=download_extract_zip('https://s3.amazonaws.com/data-eng-homework/v1/data.zip')

# %%
def identify_new_files():

def extract_order_data(data):
    
def extract_line_item_data(data):
    
def extract_user_data(data):

# %%
for o in obj:
    data=json.load(o[1])['orders']
    break

# %%
for every row in an order:
    define variables: 
        order id, user id
    create variables:
        line item total
    transform variables:
        date vars: created at, processed at, cancelled at
            
            
def extract_order_row(order):
    order_id=order['id']
    insert into
# Out:
# [{'app_id': 129785,
#   'browser_ip': '127.0.0.1',
#   'buyer_accepts_marketing': True,
#   'cancel_reason': None,
#   'cancelled_at': None,
#   'cart_token': 'censored',
#   'checkout_id': 36913577987,
#   'checkout_token': 'censored',
#   'closed_at': None,
#   'confirmed': True,
#   'contact_email': 'censored@censored.com',
#   'created_at': '2017-11-02T19:59:06-04:00',
#   'currency': 'USD',
#   'customer_locale': None,
#   'device_id': 37,
#   'email': 'censored@censored.com',
#   'financial_status': 'paid',
#   'fulfillment_status': 'fulfilled',
#   'gateway': 'shopify_payments',
#   'id': 15355346947,
#   'landing_site': None,
#   'landing_site_ref': None,
#   'line_items': [{'id': 30988861443,
#     'product_id': 10895762755,
#     'quantity': 1,
#     'variant_id': 44971978307}],
#   'location_id': 371291,
#   'name': 'GLO37-2042300000',
#   'note': None,
#   'number': 97945,
#   'order_number': 98945,
#   'order_status_url': 'https://checkout.shopify.com/censored',
# ...
